# %%
download.file("https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2Fss06hid.csv",
                   'C:/Users/Kevin/Documents/Cursos/Coursera DS/Unit3_Getting_Cleaning_Data/Week1/test.csv')

# %%
tem<-read.table("test.csv",sep=",",header=TRUE)

# %%
sum(tem$VAL=="24",na.rm = TRUE)
# Out:
# [1] 53

# %%
tem$FES
# Out:
#    [1]  2 NA  7  1  1  2 NA NA  2 NA  7  2  1 NA NA  7  1 NA  7  1 NA NA NA NA
#   [25]  4  1 NA NA NA  7  8 NA  2  1  2  1  1  4  4  1  2  1  7  4  2 NA NA  1
#   [49] NA NA NA  1 NA  1 NA  1 NA NA  3  1  2 NA NA  2 NA NA  8  7  4 NA  8  8
#   [73]  5  4  8  2 NA NA NA NA  2 NA  1  5 NA NA  1 NA NA  2  2 NA NA  5  7  4
#   [97] NA  1  1 NA  2 NA NA  1  4 NA NA NA  2 NA  1  4 NA  1  1  8  8  5  1  1
#  [121] NA  8 NA  4  1  1  7 NA  1  2  1  1  1  1  5  2  4 NA  1 NA  7 NA NA NA
#  [145]  3  7  5  5 NA  5  8  1  4  8 NA NA NA  1 NA  2 NA  2  1  1  7  4  1  1
#  [169] NA  8  6 NA  1  1 NA NA  2 NA  1 NA  4  4  2  2  1  1 NA  3 NA  2  2  2
#  [193]  1  2 NA NA  1  2 NA  2  1  7  4 NA  1 NA  7  2  5 NA NA  1  1 NA  2  2
#  [217]  1 NA  2  1  6 NA  2 NA NA NA  4  7  4  1  3  1  1  4  2  2 NA  1  4  5
#  [241] NA  1 NA NA NA  4  4 NA  4 NA  2 NA  4  2 NA NA  2  7 NA NA  4  2 NA  1
#  [265] NA NA NA  1  3 NA NA  4  4 NA NA  2  7  2 NA NA  4 NA  4 NA NA  1 NA  5
# ...

# %%
library("xlsx")
rowIndex<-18:23
colIndex<-7:15
download.file("https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2FDATA.gov_NGAP.xlsx",
                   'C:/Users/Kevin/Documents/Cursos/Coursera DS/Unit3_Getting_Cleaning_Data/Week1/te.xlsx')

# %%
dat<-read.xlsx("te1.xlsx",sheetIndex = 1,header = TRUE,colIndex = colIndex,rowIndex=rowIndex )
dat
# Out:
#   Zip   CuCurrent PaCurrent PoCurrent Contact      Ext Fax          email
# 1 74136 0         1         0         918-491-6998   0 918-491-6659 NA
# 2 30329 1         0         0         404-321-5711  NA NA           NA
# 3 74136 1         0         0         918-523-2516   0 918-523-2522 NA
# 4 80203 0         1         0         303-864-1919   0 NA           NA
# 5 80120 1         0         0         345-098-8890 456 NA           NA
#   Status
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1

# %%
sum(dat$Zip*dat$Ext,na.rm=T)
# Out:
# [1] 36534720

# %%
install.packages("XML")
# Out:
# Installing package into 'C:/Users/Kevin/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'XML' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Kevin\AppData\Local\Temp\Rtmpi8HbML\downloaded_packages

# %%
library("XML")

download.file("https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2Frestaurants.xml",
                   'C:/Users/Kevin/Documents/Cursos/Coursera DS/Unit3_Getting_Cleaning_Data/Week1/xml.xml')

# %%
tem<-xmlTreeParse("xml.xml",useInternalNodes =TRUE)
tem1<-xmlRoot(tem)
##tem1
names(tem1)
list1<-xpathSApply(tem1,"//zipcode",xmlValue)
sum(list1==21231)
# Out:
#   row
# "row"
# [1] 127

# %%
download.file("https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2Fss06pid.csv",
                   'C:/Users/Kevin/Documents/Cursos/Coursera DS/Unit3_Getting_Cleaning_Data/Week1/pid.csv')

# %%
library("data.table")
DT<-fread("pid.csv")
DT[,mean(pwgtp15),by=SEX]
# Out:
#   SEX V1
# 1 1   99.80667
# 2 2   96.66534

# %%
mean(DT$pwgtp15,by=sex)
# Out:
# [1] 98.21613
